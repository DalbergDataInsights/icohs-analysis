# %%
import pandas as pd
import numpy as np
from pandas import ExcelWriter
import openpyxl
import geopandas as gpd
from operator import truediv

# %%
input_path='../../data/input/dhis2/new_system/'
output_path='../../data/output/sprint3_analysis/'
shapes_path='../../data/shapes/district/districts_17_19.shp'
input_path_old='../../data/input/dhis2/old_system/'

# %%
df_Jan = pd.read_csv(input_path+'Data_elements_(Cases)_jan.csv')
df_Feb = pd.read_csv(input_path+'Data_elements_(Cases)_feb.csv')
df_Mar = pd.read_csv(input_path+'Data_elements_(Cases)_march.csv')
df_Apr = pd.read_csv(input_path+'Data_elements_(Cases)_april.csv')

# %%
districts = df_Feb[df_Feb['Data']=='033B-CD01a. Malaria (diagnosed)  - Cases']['Organisation unit']

# %%
def data_Quality(indicator):
    df = pd.DataFrame(districts).reset_index(drop=True)

    Jan = df_Jan[df_Jan['Data']==indicator].drop('Data', axis=1)
    Feb = df_Feb[df_Feb['Data']==indicator].drop('Data', axis=1)
    March = df_Mar[df_Mar['Data']==indicator].drop('Data', axis=1)
    April = df_Apr[df_Apr['Data']==indicator].drop('Data', axis=1)
    
    #print(Jan.shape[0]+ Feb.shape[0]+ March.shape[0] + April.shape[0])

    df_final = Jan.merge(Feb,on='Organisation unit', how='outer').merge(March,on='Organisation unit', how='outer').merge(April,on='Organisation unit', how='outer')
    #df_final.columns = ["Districts", "Jan_"+indicator, "Feb_"+indicator, "Mar_"+indicator, "Apr_"+indicator]
    df_final.set_index('Organisation unit',drop=True, inplace=True)
    columns = [('2020',indicator,"Jan"), ('2020',indicator,"Feb"),('2020',indicator,"Mar"),('2020',indicator,"Apr")]
    df_final.columns=pd.MultiIndex.from_tuples(columns)
    return df_final

# %%
data_Quality('033B-CD01a. Malaria (diagnosed)  - Cases')
# Out:
#                                                         2020                   \
#                     033B-CD01a. Malaria (diagnosed)  - Cases
#                                                          Jan      Feb     Mar
# Organisation unit
# Amuria District                                       2025.0   6710.0  7877.0
# Amuru District                                        5622.0   9317.0  8246.0
# Sironko District                                       398.0   1964.0  1868.0
# Kitgum District                                       1944.0   6135.0  6420.0
# Kitagwenda District                                    537.0   2732.0  1926.0
# ...                                                      ...      ...     ...
# Karenga District                                        46.0   1614.0  1607.0
# Mayuge District                                       2625.0  12442.0  9096.0
# Moroto District                                       1285.0   3315.0  1734.0
# Sembabule District                                    3671.0   4672.0  2309.0
# Amudat District                                          NaN   1328.0   568.0
#
#
#
#                          Apr
# Organisation unit
# Amuria District       9388.0
# Amuru District       10237.0
# Sironko District      1841.0
# Kitgum District       7846.0
# Kitagwenda District   2765.0
# ...                      ...
# Karenga District      1470.0
# Mayuge District       7701.0
# Moroto District       2439.0
# Sembabule District    2545.0
# Amudat District       1388.0
#
# [135 rows x 4 columns]

# %% [markdown]
# # Data elements

# %%
multi_index=pd.MultiIndex.from_tuples([('Test','test','test')])
data_elements=pd.DataFrame(index=districts,columns=multi_index)

# %%
indicators = df_Jan['Data'].unique()
for indicator in indicators:
    df_months = data_Quality(indicator)
    data_elements = pd.merge(data_elements, df_months, how='left',left_index=True,right_index=True)

# %%
data_elements
# Out:
#                      Test                                              2020  \
#                      test 033B-TB04. New and Relapse TB cases started on TX
#                      test                                               Jan
# Organisation unit
# Amuria District       NaN                                               NaN
# Sironko District      NaN                                               6.0
# Kitgum District       NaN                                               2.0
# Kitagwenda District   NaN                                               NaN
# Kaberamaido District  NaN                                               3.0
# ...                   ...                                               ...
# Ntungamo District     NaN                                               NaN
# Bududa District       NaN                                               2.0
# Karenga District      NaN                                               NaN
# Mayuge District       NaN                                               NaN
# Sembabule District    NaN                                               NaN
#
#                                                                             \
#                                        033B-RV07. RE Blister of 28 tablets
#                        Feb   Mar   Apr                                 Jan
# Organisation unit
# Amuria District        4.0   8.0   2.0                                 NaN
# Sironko District       9.0   7.0   NaN                                29.0
# Kitgum District       33.0  16.0  24.0                               792.0
# Kitagwenda District   10.0  13.0   5.0                                 NaN
# Kaberamaido District   6.0   NaN   1.0                               458.0
# ...                    ...   ...   ...                                 ...
# Ntungamo District     37.0  26.0  42.0                                46.0
# Bududa District        7.0   8.0   6.0                              8420.0
# Karenga District       NaN   6.0   3.0                                 NaN
# Mayuge District       11.0  26.0  24.0                                 NaN
# Sembabule District     1.0   9.0  12.0                              1632.0
#
#                                                    \
#
#                           Feb       Mar       Apr
# Organisation unit
# Amuria District         470.0     782.0    3740.0
# Sironko District      10312.0    7973.0   11770.0
# Kitgum District       14510.0   12564.0   80269.0
# Kitagwenda District    1400.0    1036.0    2815.0
# Kaberamaido District   1209.0    1488.0    1232.0
# ...                       ...       ...       ...
# Ntungamo District     66951.0  121424.0   57038.0
# Bududa District        5604.0   96190.0  158584.0
# Karenga District        713.0    1150.0    1993.0
# Mayuge District       11615.0    6412.0   12580.0
# Sembabule District     5329.0   10678.0    7385.0
#
#                                                      ...  \
#                      033B-CD02a. Dysentery  - Cases  ...
#                                                 Jan  ...
# Organisation unit                                    ...
# Amuria District                                 NaN  ...
# Sironko District                                NaN  ...
# Kitgum District                                39.0  ...
# Kitagwenda District                             NaN  ...
# Kaberamaido District                            NaN  ...
# ...                                             ...  ...
# Ntungamo District                               NaN  ...
# Bududa District                                 NaN  ...
# Karenga District                                NaN  ...
# Mayuge District                                 NaN  ...
# Sembabule District                              NaN  ...
#
#                                                                   \
#                      033B-CD14d. Hepatitis B- Cases Positive
#                                                          Mar Apr
# Organisation unit
# Amuria District                                          NaN NaN
# Sironko District                                         NaN NaN
# Kitgum District                                          NaN NaN
# Kitagwenda District                                      NaN NaN
# Kaberamaido District                                     NaN NaN
# ...                                                      ...  ..
# Ntungamo District                                        NaN NaN
# Bududa District                                          NaN NaN
# Karenga District                                         NaN NaN
# Mayuge District                                          NaN NaN
# Sembabule District                                       NaN NaN
#
#                                                                             \
#                      033B-CD13d. Typhoid Fever- Cases Positive
#                                                            Jan Feb Mar Apr
# Organisation unit
# Amuria District                                            NaN NaN NaN NaN
# Sironko District                                           NaN NaN NaN NaN
# Kitgum District                                            NaN NaN NaN NaN
# Kitagwenda District                                        NaN NaN NaN NaN
# Kaberamaido District                                       NaN NaN NaN NaN
# ...                                                        ...  ..  ..  ..
# Ntungamo District                                          NaN NaN NaN NaN
# Bududa District                                            NaN NaN NaN NaN
# Karenga District                                           NaN NaN NaN NaN
# Mayuge District                                            NaN NaN NaN NaN
# Sembabule District                                         NaN NaN NaN NaN
#
#                                                                             \
#                      033B-HI11b. Adverse Drug Reactions (ADR) - Deaths
#                                                                    Jan Feb
# Organisation unit
# Amuria District                                                    NaN NaN
# Sironko District                                                   NaN NaN
# Kitgum District                                                    NaN NaN
# Kitagwenda District                                                NaN NaN
# Kaberamaido District                                               NaN NaN
# ...                                                                ...  ..
# Ntungamo District                                                  NaN NaN
# Bududa District                                                    NaN NaN
# Karenga District                                                   NaN NaN
# Mayuge District                                                    NaN NaN
# Sembabule District                                                 NaN NaN
#
#
#
#                      Mar Apr
# Organisation unit
# Amuria District      NaN NaN
# Sironko District     NaN NaN
# Kitgum District      NaN NaN
# Kitagwenda District  NaN NaN
# Kaberamaido District NaN NaN
# ...                   ..  ..
# Ntungamo District    NaN NaN
# Bududa District      NaN NaN
# Karenga District     NaN NaN
# Mayuge District      NaN NaN
# Sembabule District   NaN NaN
#
# [135 rows x 393 columns]

# %%
data_elements.drop('test',axis=1,inplace=True,level=2)

# %%
null_sum1= data_elements.count()/135

# %% [markdown]
# # Indicators

# %%
df_Jan = pd.read_csv(input_path+'Indicator_January.csv')
df_Feb = pd.read_csv(input_path+'Indicator_Feb.csv')
df_Mar = pd.read_csv(input_path+'Indicator_march.csv')
df_Apr = pd.read_csv(input_path+'Indicator_April.csv')

# %%
districts = df_Feb[df_Feb['Data']=='EPI - BCG doses given']['Organisation unit'].unique()
multi_index=pd.MultiIndex.from_tuples([('Test','test','test')])

# %%
data_Indicators=pd.DataFrame(index=districts,columns=multi_index)

# %%
indicators = df_Jan['Data'].unique()
for indicator in indicators:
    df_months = data_Quality(indicator)
    data_Indicators = pd.merge(data_Indicators, df_months, how='left',left_index=True,right_index=True)

# %%
data_Indicators.reset_index(inplace=True)
data_Indicators=data_Indicators.groupby('index',axis=0).mean() # This shouldnt be needed, there might be a bug
# Out:
# C:\Users\Dalberg\anaconda3\envs\icohs\lib\site-packages\pandas\core\generic.py:3936: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   obj = obj._drop_axis(labels, axis, level=level, errors=errors)

# %%
null_sum2= data_Indicators.count()/135

# %% [markdown]
# # Putting the data together and matching district to shapefiles

# %%
# Looking at data quality and null data in one place

null_sum=pd.concat([null_sum1,null_sum2])
null_sum_df = pd.DataFrame(null_sum)
null_sum_df.columns = ['% of data available']
null_sum_df.index.rename(['year','indicator','month'],inplace=True)
null_av_df=null_sum_df.groupby('indicator')['% of data available'].mean()

# %%
#Putting both our data together
data=pd.merge(data_Indicators,data_elements,how='inner',left_index=True,right_index=True)

# %%
# Using the same name format as in our shapefile

data.rename(index=lambda s: s [:-9],inplace=True)
data.rename(index=str.upper,inplace=True)

# %%
data.head()
# Out:
#                                                      2020                 \
#          105- Total Linked to HIV care (1-4 Yrs) - Female
#                                                       Jan  Feb  Mar  Apr
# ABIM                                                  NaN  0.0  0.0  2.0
# ADJUMANI                                              1.0  1.0  NaN  0.0
# AGAGO                                                 0.0  0.0  0.0  1.0
# ALEBTONG                                              NaN  NaN  1.0  NaN
# AMOLATAR                                              0.0  NaN  1.0  NaN
#
#                                                                         \
#          105- Total Linked to HIV care (1-4 Yrs) - Male
#                                                     Jan  Feb  Mar  Apr
# ABIM                                                NaN  0.0  0.0  NaN
# ADJUMANI                                            1.0  0.0  3.0  1.0
# AGAGO                                               0.0  2.0  1.0  0.0
# ALEBTONG                                            1.0  NaN  NaN  NaN
# AMOLATAR                                            2.0  NaN  NaN  1.0
#
#                                                                  ...  \
#          105- Total Linked to HIV care (10-14Yrs) - Female       ...
#                                                        Jan  Feb  ...
# ABIM                                                   NaN  NaN  ...
# ADJUMANI                                               0.0  0.0  ...
# AGAGO                                                  0.0  1.0  ...
# ALEBTONG                                               0.0  1.0  ...
# AMOLATAR                                               0.0  NaN  ...
#
#                                                       \
#          033B-CD14d. Hepatitis B- Cases Positive
#                                              Mar Apr
# ABIM                                         NaN NaN
# ADJUMANI                                     NaN NaN
# AGAGO                                        NaN NaN
# ALEBTONG                                     NaN NaN
# AMOLATAR                                     NaN NaN
#
#                                                                 \
#          033B-CD13d. Typhoid Fever- Cases Positive
#                                                Jan Feb Mar Apr
# ABIM                                           NaN NaN NaN NaN
# ADJUMANI                                       NaN NaN NaN NaN
# AGAGO                                          NaN NaN NaN NaN
# ALEBTONG                                       NaN NaN NaN NaN
# AMOLATAR                                       NaN NaN NaN NaN
#
#
#          033B-HI11b. Adverse Drug Reactions (ADR) - Deaths
#                                                        Jan Feb Mar Apr
# ABIM                                                   NaN NaN NaN NaN
# ADJUMANI                                               NaN NaN NaN NaN
# AGAGO                                                  NaN NaN NaN NaN
# ALEBTONG                                               NaN NaN NaN NaN
# AMOLATAR                                               NaN NaN NaN NaN
#
# [5 rows x 1444 columns]

# %%
# Modifying the names to extacly fit whats in the shapefile

shapes = gpd.read_file(shapes_path)

# %%
# Creating a dict of names to replce (two slighly diffferent spellings )

def get_district_name_dict (df):
    keys = list(set(df.index).difference(set(shapes['name_19'])))
    values = list(set(shapes['name_19']).difference(set(df.index)))
    district_name = dict(zip(keys, values))
    return district_name

# %%
data.rename(index=get_district_name_dict(data),inplace=True)

print(list(set(data.index).difference(set(shapes['name_19']))))
# Out:
# []

# %% [markdown]
# # Selecting both relevant and well reported indicators

# %%
# Relevant ones, based on my manual selection

target = pd.read_excel(input_path+'Data summary.xlsx',sheet_name='target')

# %%
# Well reported ones, based on number of nulls

#null_av_df.to_csv(output_path+'null_values_summary.csv')

with ExcelWriter(input_path+'Data summary.xlsx',mode='a') as writer:
   null_av_df.to_excel(writer,sheet_name='null_values_summary')

# %%
#both

target = pd.merge(target,null_av_df,left_on='Var',right_on='indicator',how='left')
target['keep']=(target['% of data available']>0.7)

# %%
target_indicators=list(target.loc[target['keep']==1,'Var'])

# %% [markdown]
# # Look at EPI data

# %%
epi_target=['EPI - BCG doses given',
            #'EPI - BCG to MR 1 dropout rate (%)',
            #'EPI - DPT 1 to DPT3 dropout rate (%)',
            #'EPI - HPV1 doses given',
            #'EPI - HPV2 doses given',
            'EPI - PCV 1 doses_Under 1',
            #'EPI - PCV 2 doses_Under 1',
            'EPI - PCV 3 doses_Under 1',
            'EPI - MR 1 doses given',
            #'EPI - MR 2 doses given']
            'EPI - DPT-HepB-HIB 1 doses given',
            'EPI - DPT-HepB-HIB 3 doses given']
            

# HPV1&2 + MR2 excluded due to low or unstable reporting rates
# PCV2 is excluded to include only first and last dose (mirroring DPT HepB)
# Drop out rates excluded because theyinclude consistently negative drop out rates

# %%
new_epi=data.iloc[:, data.columns.get_level_values(1).isin(epi_target)].copy()
#new_epi.reset_index(inplace=True)

# %%
# Is the delta over 4 month the best measure?

print(null_sum.loc['2020',epi_target,['Jan','Feb','Mar','Apr']])

# Looks like yes, as the reporting rates seem steady over the period
# Out:
# year  indicator                         month
# 2020  EPI - BCG doses given             Jan      1.0
#                                         Feb      1.0
#                                         Mar      1.0
#                                         Apr      1.0
#       EPI - PCV 1 doses_Under 1         Jan      1.0
#                                         Feb      1.0
#                                         Mar      1.0
#                                         Apr      1.0
#       EPI - PCV 3 doses_Under 1         Jan      1.0
#                                         Feb      1.0
#                                         Mar      1.0
#                                         Apr      1.0
#       EPI - DPT-HepB-HIB 1 doses given  Jan      1.0
#                                         Feb      1.0
#                                         Mar      1.0
#                                         Apr      1.0
#       EPI - DPT-HepB-HIB 3 doses given  Jan      1.0
#                                         Feb      1.0
#                                         Mar      1.0
#                                         Apr      1.0
#       EPI - MR 1 doses given            Jan      1.0
#                                         Feb      1.0
#                                         Mar      1.0
#                                         Apr      1.0
# dtype: float64

# %%
def get_delta(df,st_year,end_year,indic,st_month,end_month):
    delta=((df[(end_year,indicator,end_month)]
            -df[(st_year,indicator,st_month)])
           /df[(st_year,indicator,st_month)])
    return delta

# %%
for indicator in epi_target:
    new_epi[('2020',indicator,'delta_jan_20_apr_20')]=get_delta(df=new_epi,
                                                        st_year='2020',
                                                        end_year='2020',
                                                        indic=indicator,
                                                        st_month='Jan',
                                                        end_month='Apr')

# %%
new_epi
# Out:
#                           2020                          \
#          EPI - BCG doses given
#                            Jan     Feb     Mar     Apr
# ABIM                     354.0   294.0   342.0   310.0
# ADJUMANI                 976.0  1055.0   866.0   864.0
# AGAGO                    736.0   667.0   670.0   510.0
# ALEBTONG                 809.0   744.0   654.0   656.0
# AMOLATAR                 440.0   544.0   490.0   316.0
# ...                        ...     ...     ...     ...
# SOROTI                  1242.0  1064.0  1167.0   942.0
# TORORO                  1816.0  1571.0  1664.0  1325.0
# WAKISO                  8464.0  6552.0  6298.0  3622.0
# YUMBE                   1371.0  1188.0  1410.0  1469.0
# ZOMBO                    586.0   766.0   859.0   581.0
#
#                                                             \
#          EPI - PCV 1 doses_Under 1
#                                Jan     Feb     Mar     Apr
# ABIM                         336.0   304.0   421.0   356.0
# ADJUMANI                    1157.0   991.0   937.0   836.0
# AGAGO                        744.0   733.0   968.0   575.0
# ALEBTONG                     838.0   786.0   789.0   817.0
# AMOLATAR                     543.0   521.0   612.0   389.0
# ...                            ...     ...     ...     ...
# SOROTI                      1068.0  1061.0  1170.0   933.0
# TORORO                      1914.0  1761.0  1533.0  3733.0
# WAKISO                      8377.0  8662.0  7681.0  3815.0
# YUMBE                       2118.0  1915.0  2138.0  1760.0
# ZOMBO                        874.0   783.0   807.0   755.0
#
#                                             ...                         \
#          EPI - PCV 3 doses_Under 1          ... EPI - MR 1 doses given
#                                Jan     Feb  ...                    Jan
# ABIM                         382.0   280.0  ...                  273.0
# ADJUMANI                    1203.0  1064.0  ...                 1172.0
# AGAGO                        810.0   823.0  ...                  654.0
# ALEBTONG                     985.0   900.0  ...                  737.0
# AMOLATAR                     479.0   501.0  ...                  463.0
# ...                            ...     ...  ...                    ...
# SOROTI                      1062.0  1075.0  ...                  996.0
# TORORO                      1911.0  1959.0  ...                 1555.0
# WAKISO                      7737.0  7997.0  ...                 8881.0
# YUMBE                       2083.0  1952.0  ...                 2047.0
# ZOMBO                        842.0   951.0  ...                  869.0
#
#                                                         \
#                                  EPI - BCG doses given
#              Feb     Mar     Apr   delta_jan_20_apr_20
# ABIM       300.0   452.0   381.0             -0.124294
# ADJUMANI  1209.0  1001.0   795.0             -0.114754
# AGAGO      679.0   914.0   641.0             -0.307065
# ALEBTONG   727.0   664.0   682.0             -0.189122
# AMOLATAR   608.0   585.0   320.0             -0.281818
# ...          ...     ...     ...                   ...
# SOROTI     994.0  1024.0   878.0             -0.241546
# TORORO    1762.0  1413.0  1487.0             -0.270374
# WAKISO    8123.0  7236.0  3662.0             -0.572070
# YUMBE     1943.0  2053.0  1666.0              0.071481
# ZOMBO      808.0   910.0   604.0             -0.008532
#
#                                                               \
#          EPI - PCV 1 doses_Under 1 EPI - PCV 3 doses_Under 1
#                delta_jan_20_apr_20       delta_jan_20_apr_20
# ABIM                      0.059524                 -0.133508
# ADJUMANI                 -0.277442                 -0.291771
# AGAGO                    -0.227151                 -0.154321
# ALEBTONG                 -0.025060                 -0.098477
# AMOLATAR                 -0.283610                 -0.304802
# ...                            ...                       ...
# SOROTI                   -0.126404                 -0.177024
# TORORO                    0.950366                 -0.188906
# WAKISO                   -0.544586                 -0.554995
# YUMBE                    -0.169027                 -0.156505
# ZOMBO                    -0.136156                 -0.111639
#
#                                                                   \
#          EPI - MR 1 doses given EPI - DPT-HepB-HIB 1 doses given
#             delta_jan_20_apr_20              delta_jan_20_apr_20
# ABIM                   0.395604                         0.369048
# ADJUMANI              -0.321672                        -0.287788
# AGAGO                 -0.019878                        -0.247382
# ALEBTONG              -0.074627                        -0.027381
# AMOLATAR              -0.308855                        -0.207721
# ...                         ...                              ...
# SOROTI                -0.118474                        -0.087084
# TORORO                -0.043730                        -0.182807
# WAKISO                -0.587659                        -0.552712
# YUMBE                 -0.186126                        -0.180633
# ZOMBO                 -0.304948                        -0.129693
#
#
#          EPI - DPT-HepB-HIB 3 doses given
#                       delta_jan_20_apr_20
# ABIM                            -0.128947
# ADJUMANI                        -0.270798
# AGAGO                           -0.151478
# ALEBTONG                        -0.101215
# AMOLATAR                        -0.268041
# ...                                   ...
# SOROTI                          -0.173913
# TORORO                          -0.195248
# WAKISO                          -0.555405
# YUMBE                           -0.169571
# ZOMBO                           -0.128000
#
# [135 rows x 30 columns]

# %% [markdown]
# Weird phenomenon : negative drop out rates
#
# "Check for inconsistency in related indicators – **An example of such inconsistency is when there is a negative dropout over a full year** between the number of children receiving the first dose of DPT vaccine and the number receiving the third dose of the vaccine.  Another example, as illustrated in Figure 1 above, is inconsistency between the number of children receiving DPT vaccine and the number of children receiving OPV vaccine.  Yet another example is when there is a negative “wastage rate” (discussed below) -- when the number of children reported to have received a vaccine is greater than the number of doses of the vaccine reported to have been consumed."
#
# from this [WHO document](https://www.who.int/healthinfo/FacilityAnalysisGuide_Immunization.pdf?ua=1#page=11)

# %% [markdown]
# # Add in the EPI data from the old DHIS2 instance

# %%
old_epi=pd.read_csv(input_path_old+'epi_data_2018_19.csv')

# %%
# Get the data we are interested in, using the right index

old_epi['district']=old_epi['organisationunitname'].apply(lambda x: x[:-9].upper())
old_epi.set_index('district',drop=True,inplace=True)
cols = np.arange(0,4)
old_epi.drop(old_epi.columns[cols],axis=1,inplace=True)
old_epi.rename(index=get_district_name_dict(old_epi),inplace=True)

# %%
# build a small fucntion to split the string column name

def split(strng, sep, occ):
    strng = strng.split(sep)
    return sep.join(strng[occ[1]:]), sep.join(strng[:occ[0]]), sep.join(strng[occ[0]:occ[1]])[:3]

# %%
# Get the right column multiindex

occurences =[-2,-1]
separator = " "
cols=old_epi.columns
new_cols=[]
for col in cols:
    new_cols.append(split(col,separator,occurences))
    
old_epi.columns=pd.MultiIndex.from_tuples(new_cols)

# %%
# drop the period Iam not interested in for now, to be updated if nw data comes in

dropped_months=['Jun','Jul','Aug','Sep','Oct','Nov','Dec']
old_epi.drop(dropped_months,axis=1,inplace=True,level=2)

# %%
# Use the same naming convention for indicator as the new DHIS2 instance

old_names= list(old_epi.columns.levels[1])

new_names = ['EPI - DPT-HepB-HIB 1 doses given',
            'EPI - DPT-HepB-HIB 2 doses given',
            'EPI - DPT-HepB-HIB 3 doses given',
            'EPI - BCG doses given',
            'EPI - HPV1 doses given',
            'EPI - HPV2 doses given',
            'EPI - HPV3 doses given',
            'EPI - MR 1 doses given',
            'EPI - PCV 1 doses_Under 1',
            'EPI - PCV 2 doses_Under 1',
            'EPI - PCV 3 doses_Under 1']
            
indicator_name = dict(zip(old_names, new_names))
old_epi.columns.set_levels(list(indicator_name.values()),level=1,inplace=True)

indicator_name
# Out:
# {'DPT1 Under1': 'EPI - DPT-HepB-HIB 1 doses given',
#  'DPT2 Under1': 'EPI - DPT-HepB-HIB 2 doses given',
#  'DPT3 Under1': 'EPI - DPT-HepB-HIB 3 doses given',
#  'EPI - BCG doses given': 'EPI - BCG doses given',
#  'HPV1': 'EPI - HPV1 doses given',
#  'HPV2': 'EPI - HPV2 doses given',
#  'HPV3': 'EPI - HPV3 doses given',
#  'Measles Under1': 'EPI - MR 1 doses given',
#  'PCV 1 Under1': 'EPI - PCV 1 doses_Under 1',
#  'PCV 2 Under1': 'EPI - PCV 2 doses_Under 1',
#  'PCV 3 Under1': 'EPI - PCV 3 doses_Under 1'}

# %%
# get the Jan-Apr deltas for 2019

for indicator in epi_target:
    old_epi[('2019',indicator,'delta_jan_19_apr_19')]=get_delta(df=old_epi,
                                                        st_year='2019',
                                                        end_year='2019',
                                                        indic=indicator,
                                                        st_month='Jan',
                                                        end_month='Apr')

# %%
old_epi
# Out:
#                                      2018                          \
#          EPI - DPT-HepB-HIB 1 doses given
#                                       Jan   Feb   Mar   Apr   May
# district
# ABIM                                  393   324   292   276   357
# ADJUMANI                              949   822   787   798   992
# AGAGO                                 908   876   879   824   815
# ALEBTONG                              866   694   755   641   772
# AMOLATAR                              781   619   566   559   587
# ...                                   ...   ...   ...   ...   ...
# SOROTI                               1163   968  1132   935  1022
# TORORO                               1907  1475  1527  1466  1981
# WAKISO                               8712  7878  8415  8640  8364
# YUMBE                                2545  2383  2209  2750  2565
# ZOMBO                                 918   819   729   816   939
#
#                                      2019                          ...  \
#          EPI - DPT-HepB-HIB 1 doses given                          ...
#                                       Jan   Feb   Mar   Apr   May  ...
# district                                                           ...
# ABIM                                  479   421   507   486   379  ...
# ADJUMANI                             1183  1063   969   963  1044  ...
# AGAGO                                 880   899  1075   775   947  ...
# ALEBTONG                              956  1017   956   857   909  ...
# AMOLATAR                              645   674   656   625   659  ...
# ...                                   ...   ...   ...   ...   ...  ...
# SOROTI                               1359  1140  1088  1148  1294  ...
# TORORO                               2113  2659  1765  1771  3457  ...
# WAKISO                               8263  8613  8816  7888  9552  ...
# YUMBE                                3908  2230  2258  2323  3271  ...
# ZOMBO                                1001   763   895   959  1069  ...
#
#                                                                          \
#          EPI - MR 1 doses given                   EPI - BCG doses given
#                             Feb   Mar   Apr   May   delta_jan_19_apr_19
# district
# ABIM                        393   411   530   497             -0.178218
# ADJUMANI                   1163  1280   903  1041             -0.157058
# AGAGO                       587   780   659   707             -0.063786
# ALEBTONG                    728   749   793   839             -0.262615
# AMOLATAR                    450   471   471   529             -0.196429
# ...                         ...   ...   ...   ...                   ...
# SOROTI                      842  1009  1023  1064             -0.120654
# TORORO                     1515  1625  1565  3069             -0.026240
# WAKISO                     8539  9420  8479  9824             -0.034970
# YUMBE                      4131  2255  2268  2425             -0.073573
# ZOMBO                       805   786   739   849              0.383091
#
#                                                               \
#          EPI - PCV 1 doses_Under 1 EPI - PCV 3 doses_Under 1
#                delta_jan_19_apr_19       delta_jan_19_apr_19
# district
# ABIM                      0.014170                  0.198675
# ADJUMANI                 -0.156574                 -0.093110
# AGAGO                    -0.125440                 -0.001096
# ALEBTONG                 -0.115304                 -0.002132
# AMOLATAR                 -0.030207                  0.042032
# ...                            ...                       ...
# SOROTI                   -0.030970                 -0.045494
# TORORO                   -0.130049                 -0.101687
# WAKISO                   -0.063883                  0.006990
# YUMBE                    -0.402458                 -0.142118
# ZOMBO                    -0.082353                 -0.163966
#
#                                                                   \
#          EPI - MR 1 doses given EPI - DPT-HepB-HIB 1 doses given
#             delta_jan_19_apr_19              delta_jan_19_apr_19
# district
# ABIM                   0.226852                         0.014614
# ADJUMANI              -0.070988                        -0.185968
# AGAGO                  0.185252                        -0.119318
# ALEBTONG               0.070175                        -0.103556
# AMOLATAR               0.021692                        -0.031008
# ...                         ...                              ...
# SOROTI                 0.222222                        -0.155261
# TORORO                -0.084260                        -0.161855
# WAKISO                 0.056178                        -0.045383
# YUMBE                 -0.568000                        -0.405578
# ZOMBO                  0.077259                        -0.041958
#
#
#          EPI - DPT-HepB-HIB 3 doses given
#                       delta_jan_19_apr_19
# district
# ABIM                             0.191630
# ADJUMANI                        -0.073284
# AGAGO                            0.003236
# ALEBTONG                         0.024919
# AMOLATAR                         0.001698
# ...                                   ...
# SOROTI                          -0.132540
# TORORO                          -0.175587
# WAKISO                           0.053174
# YUMBE                           -0.080446
# ZOMBO                           -0.155450
#
# [135 rows x 116 columns]

# %% [markdown]
# # Pull all in one df

# %%
epi_df=pd.merge(new_epi,old_epi,how='inner',left_index=True,right_index=True)
#new_epi.columns=new_epi.columns.map("_".join)

# %%
def get_yoy_delta(df,indic,period):
    tot_18 = tot_19= tot_20 = np.zeros(135)
    for month in period:
        tot_18= tot_18+list(epi_df[('2018',indic,month)])
        tot_19= tot_19+list(epi_df[('2019',indic,month)])
        tot_20= tot_20+list(epi_df[('2020',indic,month)])
    delta =  (tot_20-tot_19)/tot_19
    return tot_18,tot_19,tot_20,delta

# %%
#get_yoy_delta(epi_df,'EPI - BCG doses given',period)

# %%
# get the Mar+Apr deltas for 2019 vs 2020
period=['Mar','Apr']

for indicator in epi_target:
    (epi_df[('2018',indicator,'period_total')],
    epi_df[('2019',indicator,'period_total')],
    epi_df[('2020',indicator,'period_total')],
    epi_df[('2020',indicator,'delta_per_19_per_20')]) = get_yoy_delta(epi_df,indicator,period)

# %% [markdown]
# # Get that to CSV

# %%
epi_export_df=epi_df.copy()
epi_export_df.columns=epi_df.columns.map("_".join)
epi_export_df.to_csv(output_path+'epi_map.csv')
